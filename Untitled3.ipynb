# %% [markdown]
# <a href="https://colab.research.google.com/github/Raulfb04/EDP-1/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#En este ejercicio estamos practicando como realizar un código en Google Colab para posteriormente guardarlo en Github.

# prompt: Grafica $y=x^2$

import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(-5, 5, 100)
y = x**2

plt.plot(x, y)
plt.xlabel("x")
plt.ylabel("y")
plt.title("Grafica de $y = x^2$", color='green')
plt.show()
