# %% [markdown]
# <a href="https://colab.research.google.com/github/Raulfb04/EDP-1/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# prompt: grafica z=x^2 + y^2

import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Create the figure and axes object
fig = plt.figure(figsize=(12, 12))
ax = fig.add_subplot(projection="3d")

# Create the meshgrid
num_points = 100
x = np.linspace(-5, 5, num_points)
y = np.linspace(-5, 5, num_points)
X, Y = np.meshgrid(x, y)

# Calculate Z
Z = X**2 + Y**2

# Plot the surface
ax.plot_surface(X, Y, Z, cmap="viridis")

# Add labels and title
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_zlabel("z")
ax.set_title("Plot of z = x^2 + y^2")

# Show the plot
plt.show()

# %% [markdown]
# # Nueva sección
